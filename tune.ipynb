# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('file.csv')#load data

# %%
train_df.head(5)#show brief data
# Out:
#    Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 0   37       0              0               0          1               3
# 1   44       1              0               0          0               1
# 2   32       1              0               0          0               1
# 3   31       1              0               1          1               3
# 4   31       1              0               0          0               0
#
#    no_employees  remote_work  tech_company  benefits  ...  seek_help  \
# 0             1            0             1         1  ...          1
# 1             5            0             0         0  ...          0
# 2             1            0             1         0  ...          0
# 3             2            0             1         0  ...          0
# 4             3            1             1         1  ...          0
#
#    anonymity  leave  mental_health_consequence  phys_health_consequence  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
# Scaling Age
scaler = MinMaxScaler()
train_df['Age'] = scaler.fit_transform(train_df[['Age']])
train_df.head()
# Out:
#         Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 0  0.351852       0              0               0          1               3
# 1  0.481481       1              0               0          0               1
# 2  0.259259       1              0               0          0               1
# 3  0.240741       1              0               1          1               3
# 4  0.240741       1              0               0          0               0
#
#    no_employees  remote_work  tech_company  benefits  ...  seek_help  \
# 0             1            0             1         1  ...          1
# 1             5            0             0         0  ...          0
# 2             1            0             1         0  ...          0
# 3             2            0             1         0  ...          0
# 4             3            1             1         1  ...          0
#
#    anonymity  leave  mental_health_consequence  phys_health_consequence  \
# ...

# %%
from sklearn.model_selection import train_test_split
# define determinants and consequence
feature_cols=['Age', 'Gender', 'family_history', 'benefits', 'care_options', 'anonymity', 'leave', 'work_interfere','no_employees']
determinants = train_df[feature_cols]
consequence=train_df.treatment

x_train,x_test,y_train,y_test=train_test_split(determinants,consequence,test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import roc_curve,accuracy_score,recall_score

# %%
import time
import psutil
titles = ['LogisticRegression','SVM','RandomForest']
classifers = [
    LogisticRegression(random_state=0,penalty='l2'),
    RandomForestClassifier(bootstrap=True, random_state=0),
    LinearSVC(random_state=0, tol=1e-5)
]
for title,classifer in zip(titles,classifers):
    print('\n --- Start Model : %s ----\n'%title)
    start = time.clock()
    md=classifer.fit(x_train,y_train)
    print(md)
    #mem = psutil.virtual_memory()
    #print('使用内存：', mem.used)
    y_predict = classifer.predict(x_test)
    end = time.clock()
    score = classifer.score(x_test,y_test)
    recall = recall_score(y_test,y_predict)
    print(score)
    print(recall)
    print('Running time: %s Seconds'%(end-start))
# Out:
#  --- Start Model : LogisticRegression ----
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   # This is added back by InteractiveShellApp.init_path()
# E:\anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
# 0.7908847184986595
# 0.8324324324324325
# Running time: 1.0725337639996724 Seconds
#
#  --- Start Model : SVM ----
#
# ...

# %%
from keras import layers
from keras import models
model = models.Sequential()
model.add(layers.Dense(16,activation='relu',input_shape=(9,)))
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_101 (Dense)            (None, 16)                160
# _________________________________________________________________
# dense_102 (Dense)            (None, 16)                272
# _________________________________________________________________
# dense_103 (Dense)            (None, 1)                 17
# ...
# Total params: 449
# Trainable params: 449
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = np.asarray(x_train).astype('float32')
x_test = np.asarray(x_test).astype('float32')
y_train = np.asarray(y_train).astype('float32')
y_test = np.asarray(y_test).astype('float32')

# %%
import keras.backend as K
def getPrecision(y_true, y_pred):
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))#TP
    N = (-1)*K.sum(K.round(K.clip(y_true-K.ones_like(y_true), -1, 0)))#N
    TN=K.sum(K.round(K.clip((y_true-K.ones_like(y_true))*(y_pred-K.ones_like(y_pred)), 0, 1)))#TN
    FP=N-TN
    precision = TP / (TP + FP + K.epsilon())#TT/P
    return precision

def getRecall(y_true, y_pred):
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))#TP
    P=K.sum(K.round(K.clip(y_true, 0, 1)))
    FN = P-TP #FN=P-TP
    recall = TP / (TP + FN + K.epsilon())#TP/(TP+FN)
    return recall

# %%
model.compile(optimizer='rmsprop',
             loss='binary_crossentropy',
             metrics=['accuracy',getRecall])
#model.fit(x_train,y_train,validation_split=0.10,epochs=5,batch_size=8)
model.fit(x_train,y_train,epochs=8,batch_size=8)
# Out:
# Epoch 1/8
# 870/870 [==============================] - 0s 531us/step - loss: 0.6216 - accuracy: 0.7126 - getRecall: 0.6880
# Epoch 2/8
# 870/870 [==============================] - 0s 383us/step - loss: 0.5447 - accuracy: 0.7713 - getRecall: 0.7766
# Epoch 3/8
# 870/870 [==============================] - 0s 383us/step - loss: 0.4827 - accuracy: 0.8023 - getRecall: 0.8638
# Epoch 4/8
# 870/870 [==============================] - 0s 386us/step - loss: 0.4422 - accuracy: 0.8138 - getRecall: 0.8804
# Epoch 5/8
# 870/870 [==============================] - 0s 405us/step - loss: 0.4186 - accuracy: 0.8310 - getRecall: 0.8744
# Epoch 6/8
# 870/870 [==============================] - 0s 408us/step - loss: 0.4058 - accuracy: 0.8333 - getRecall: 0.8766
# Epoch 7/8
# 870/870 [==============================] - 0s 341us/step - loss: 0.3999 - accuracy: 0.8379 - getRecall: 0.9027
# Epoch 8/8
# 870/870 [==============================] - 0s 334us/step - loss: 0.3945 - accuracy: 0.8425 - getRecall: 0.9062

# %%
model.save('d1616.h5')

# %%
from keras.layers import Dense, Dropout,Convolution1D

# %%
x_train=x_train.reshape((x_train.shape[0],x_train.shape[1],1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1],1))
y_train=y_train.reshape((y_train.shape[0],1))
y_test = y_test.reshape((y_test.shape[0],1))

# %%
model2 = models.Sequential()
model2.add(Convolution1D(filters = 2, kernel_size = 4, input_shape=(9,1)))
model2.add(layers.Flatten())
model2.add(layers.Dense(8,activation='relu'))
#model2.add(Dropout(0.2))
model2.add(layers.Dense(8,activation='relu'))
#model2.add(Dropout(0.2))
model2.add(layers.Dense(1,activation='sigmoid'))
model2.summary()
model2.compile(optimizer='rmsprop',
             loss='binary_crossentropy',
             metrics=['accuracy',getRecall])
#model.fit(x_train,y_train,validation_split=0.10,epochs=5,batch_size=8)
model2.fit(x_train,y_train,epochs=10,batch_size=8)
# Out:
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_26 (Conv1D)           (None, 6, 2)              10
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dense_110 (Dense)            (None, 8)                 104
# _________________________________________________________________
# dense_111 (Dense)            (None, 8)                 72
# _________________________________________________________________
# dense_112 (Dense)            (None, 1)                 9
# ...
# Total params: 195
# Trainable params: 195
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 870/870 [==============================] - 1s 675us/step - loss: 0.6656 - accuracy: 0.6690 - getRecall: 0.8175
# ...

# %%
model2.save('d195.h5')
